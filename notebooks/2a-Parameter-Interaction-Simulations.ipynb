# %% [markdown]
# ## Parameter Interaction Simulations
#
# This notebook will simulate PSDs where two parameters sweep through a range. For example, Amplitude will sweep across a frequency range while bandwidth changes.

# %%
# Set matplotlib for plotting in the notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import rcParams

import numpy as np

from fooof.synth import *
from fooof import FOOOFGroup, FOOOF
from utils.analysis import *

# %%
plt.rcParams.update({'figure.max_open_warning': 0})

# %%
# %run "gen_interacting_parameter_data.py"

# %%
sl_amp_low = np.load("./dat/sl_amp_data_low.npy")
sl_amp_high = np.load("./dat/sl_amp_data_high.npy")

cf_bw_low = np.load("./dat/cf_bw_data_low.npy")
cf_bw_high = np.load("./dat/cf_bw_data_high.npy")

# %% [markdown]
# ## Slope Amplitude check

# %% [markdown]
# This is a sanity check that the simulated data exists for when amplitude interacts with slope.

# %%
sl_amp_low = sl_amp_low[0]
sl_amp_high = sl_amp_high[0]

# %%
freqs = sl_amp_low[1]
for psd in sl_amp_low[2]:
    fm = FOOOF(verbose=False)
    fm.add_data(freqs,psd)
    fm.fit()
    fm.plot()

# %%
freqs = sl_amp_high[1]
for psd in sl_amp_high[2]:
    fm = FOOOF(verbose=False)
    fm.add_data(freqs,psd)
    fm.fit()
    fm.plot()

# %% [markdown]
# ## Center Frequency and BandWidth

# %%
freqs = cf_bw_low[1][1]
for psd in cf_bw_low[2][2]:
    fm = FOOOF(verbose=False)
    fm.add_data(freqs,psd)
    fm.fit()
    fm.plot()

# %%
freqs = cf_bw_high[1][1]
for psd in cf_bw_high[2][2]:
    fm = FOOOF(verbose=False)
    fm.add_data(freqs,psd)
    fm.fit()
    fm.plot()
