# %%
data = read.csv("dat/Slope_sims",header=FALSE)

# %%
data
# Out:
#    V1           V2           V3
# 1  0.1500742021 1.254073e+00 1.5668106
# 2  0.4849657882 1.085422e-01 0.4326630
# 3  1.0426852316 4.872843e-02 0.5238418
# 4  0.3654262570 1.415464e-02 0.5203722
# 5  0.0293409014 8.245262e-04 0.5498329
# 6  0.1257763986 1.224620e-02 0.5561525
# 7  0.3857577813 1.540732e-02 0.5638409
# 8  0.1674615724 2.701338e-04 0.5557022
# 9  0.5823767104 1.000716e-03 0.5539266
# 10 0.5814292791 1.147243e-02 0.5633897
# 11 0.0621943093 3.833441e-03 0.5634014
# 12 0.2487870999 1.513112e-03 0.5589474
# 13 0.6546960942 1.402368e-02 0.5707292
# 14 0.0540095390 2.717554e-03 0.5584161
# 15 0.3625866891 8.956373e-03 0.5626333
# 16 0.0390336869 2.515249e-03 0.5661619
# 17 0.2471426990 3.180731e-03 0.5621055
# 18 0.0969466511 6.136022e-04 0.5621318
# 19 0.1176275150 4.874769e-03 0.5626789
# 20 0.1919847439 9.224403e-04 0.5652310
# 21 0.0287625217 2.284912e-03 0.5692296
# 22 0.1444477279 1.691221e-03 0.5645250
# 23 0.8585040563 9.208469e-03 0.5596954
# 24 0.4962143705 2.005137e-03 0.5624135
# 25 0.3021227316 5.743449e-03 0.5600304
# 26 0.0433802694 2.601074e-03 0.5644912
# 27 0.2100481849 2.209265e-03 0.5663695
# 28 0.1598598795 3.044355e-03 0.5642587
# 29 0.2730363668 7.257784e-04 0.5640209
# 30 0.2959270051 1.048740e-03 0.5687609
# 31 0.0679077332 7.731597e-04 0.5693435
# 32 0.1387018147 1.695417e-03 0.5669162
# 33 0.0957260358 4.169667e-03 0.5642775
# 34 0.3361360361 5.728436e-06 0.5663689
# 35 1.2316439061 1.287215e-03 0.5675390
# 36 0.0160233836 3.901127e-03 0.5657318
# 37 0.0024084274 2.144941e-03 0.5684121
# 38 0.4936456088 2.440174e-03 0.5664965
# 39 0.1292729937 3.963466e-03 0.5653869
# 40 0.0002635904 5.307118e-05 0.5691452
# 41 0.2891105449 7.690829e-04 0.5683468
# 42 0.6533113734 4.830153e-03 0.5703238
# 43 0.7892621035 2.707808e-03 0.5676680
# 44 0.0001011791 9.898098e-04 0.5658164
# 45 0.0541183543 1.699277e-03 0.5701754
# 46 0.4592319516 2.848123e-03 0.5681910
# 47 0.0142212950 5.913665e-04 0.5693916
# 48 1.0081823951 1.146549e-03 0.5667902
# 49 0.4749673681 1.696487e-03 0.5665417
# 50 0.2506600429 1.693080e-03 0.5684671

# %%
method1 <- data$V1
method2 <- data$V2
method3 <- data$V3

# %%
m1 <- mean(method1)

# %%
m2 <- mean(method2)

# %%
m3 <- mean(method3)

# %% [markdown]
# ## Write to output file

# %%
mat <- matrix( c(m1,m2,m3), nrow=1,ncol=3,byrow=TRUE)
dfa <- data.frame(mat)

# %%
write.csv(dfa,"dat/Slope_sim_analysis.csv")

# %%
c(m1,m2,m3)
# Out:
# [1] 0.30615005 0.03159676 0.58028187

# %%
dfa
# Out:
#   X1      X2         X3
# 1 0.30615 0.03159676 0.5802819
